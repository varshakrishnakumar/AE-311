# %%
import sympy
import numpy as np
sympy.init_printing(use_unicode=False, wrap_line=False)
i = sympy.Symbol('i')
j = sympy.Symbol('j')
delta_sj = sympy.Symbol('delta_sj')
a = sympy.Symbol('a')
b = sympy.Symbol('b')
A = sympy.Symbol('A')
B = sympy.Symbol('B')
C = sympy.Symbol('C')
D = sympy.Symbol('D')
gamj = sympy.Symbol('gamj')
gamj1 = sympy.Symbol('gamj1')
ali = sympy.Symbol('ali')
alj = sympy.Symbol('alj')
ti = sympy.Symbol('ti')
tj = sympy.Symbol('tj')
xhati = sympy.Symbol("xhati")
xhatj = sympy.Symbol("xhatj")
yhati = sympy.Symbol("yhati")
yhatj = sympy.Symbol("yhatj")
xi = sympy.Symbol('xi')
xj = sympy.Symbol('xj')
yi = sympy.Symbol('yi')
yj = sympy.Symbol('yj')
changesj = sympy.Symbol('deltasj')
sj = sympy.Symbol('sj')
f = (a*sj+b)*((A*sj+B)/(sj**2+C*sj+D))
solve = sympy.integrate(f, (sj, 0, changesj))
solve.subs({A:-sympy.cos(ti-tj), B:(xhati-xj)*sympy.cos(tj)+sympy.sin(tj)*(yhati-yj), C:2*xj*sympy.cos(tj)-2*(xhati*sympy.cos(tj))+2*yj*sympy.sin(tj)-2*yhati*sympy.sin(tj), D:(xhati-xj)**2+(yhati-yj)**2, a:(gamj1-gamj)/(changesj), b:(gamj)})
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 /                                                                                                                                                                                                                /                                                                                                                                    
# ...
